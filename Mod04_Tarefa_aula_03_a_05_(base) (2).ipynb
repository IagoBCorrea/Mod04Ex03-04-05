# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui

total = pd.DataFrame()

total['Matemática'] = pd.DataFrame(round((df_mat / 24) * 100, 2))
total['Português'] = pd.DataFrame(round((df_por / 18) * 100, 2))
total['Geografia'] = pd.DataFrame(round((df_geo / 8) * 100, 2))
total['Inglês'] = pd.DataFrame(round((df_ing / 8) * 100, 2))
total['História'] = pd.DataFrame(round((df_his / 8) * 100, 2))
total['Física'] = pd.DataFrame(round((df_fis / 12) * 100, 2))
total['Química'] = pd.DataFrame(round((df_qui / 12) * 100, 2))
total
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química
# 0        25.00      38.89       87.5    37.5      12.5   66.67    25.00
# 1        79.17      55.56        0.0     0.0       0.0   91.67    66.67
# 2        58.33      88.89        0.0    62.5      87.5   33.33    33.33
# 3        41.67      38.89       37.5    50.0       0.0    0.00    66.67
# 4        29.17      11.11       25.0    87.5       0.0   75.00    25.00
# ..         ...        ...        ...     ...       ...     ...      ...
# 95       25.00      22.22       87.5    12.5      50.0   75.00    25.00
# 96       33.33       5.56       50.0    75.0      12.5   33.33    25.00
# 97       95.83      27.78        0.0    25.0      50.0    8.33    41.67
# 98        0.00      55.56       37.5    12.5      62.5   83.33    91.67
# 99       45.83      83.33        0.0    12.5      75.0   58.33    16.67
#
# [100 rows x 7 columns]

# %%
# 2) Seu código aqui

total_acertos = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total_acertos
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui

round(total_acertos/90, 2)
# Out:
#     Qt_acertos
# 0         0.39
# 1         0.53
# 2         0.56
# 3         0.36
# 4         0.33
# ..         ...
# 95        0.38
# 96        0.30
# 97        0.44
# 98        0.44
# 99        0.47
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui

nota_maior_45 = total_acertos[total_acertos['Qt_acertos'] > 45]

nota_maior_45.count()
# Out:
# Qt_acertos    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui

df_eliminados = total[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)].sum(axis=1) == 0

df_eliminados
# Out:
# 3     False
# 6     False
# 10    False
# 12    False
# 14    False
# 20    False
# 25    False
# 26    False
# 27    False
# 33    False
# 35    False
# 49    False
# 56    False
# 65    False
# 66    False
# 72    False
# 73    False
# 74    False
# 84    False
# 89    False
# 92    False
# 94    False
# 98    False
# dtype: bool

# %%
#2

df_eliminados.size
# Out:
# 23

# %%
#3.1

media_his = df_his['Qt_acertos'].mean()
media_his
# Out:
# 3.6

# %%
#3.2

media_geo = df_geo['Qt_acertos'].mean()
media_geo
# Out:
# 3.36

# %%
#4

# Calcular o número de alunos que passaram para a segunda fase
alunos_segunda_fase = nota_maior_45 - df_eliminados

# Criar um DataFrame com o número de alunos que passaram para a segunda fase
df_segunda_fase = pd.DataFrame({'Alunos Segunda Fase': [alunos_segunda_fase]})

# Exibir o DataFrame
print(df_segunda_fase)
# Out:
#                                  Alunos Segunda Fase
# 0     Qt_acertos    3    6   10   12   14   20   ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = r'C:\Users\moona\Downloads\vacinaCOVID.csv'

# %%
df = pd.read_csv(arquivo, sep=';')
df.head()
# Out:
#                                  document_id  \
# 0  c4fe1c06-9d03-4fb3-9f09-d03ae04172ed-i0b0
# 1  5af4b0d7-be0f-4df4-87a8-c13518d4e161-i0b0
# 2  ea959b1f-c617-41f3-9114-3b3d8e6efb74-i0b0
# 3  a5178b92-4cb0-4642-9642-496a83a5f0ee-i0b0
# 4  f8c190bd-99f5-4426-8660-287026cb8f38-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  b04dc8dc9a414410e7defb82eedd78ffeba9326ffe2a5e...              14
# 1  dbb25c2d85f3fb2849d4883516b02940f96358ecd86b5b...              23
# 2  c71ae47ddab9e6bf4268c9d247781644a51f606208aa2f...              17
# 3  152e0231d0451f02a96e068260273002342e622a4bd249...              37
# 4  146286fb0daf52953daa7aa2fb5b8dffc16a53269530aa...              17
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2007-04-05                          F                       99
# 1              2000-01-21                          F                        5
# 2              2003-12-31                          F                        4
# 3              1985-03-23                          M                        4
# 4              2004-10-30                          M                        1
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0         SEM INFORMACAO                           120040.0
# 1               INDIGENA                           120042.0
# 2                AMARELA                           120040.0
# 3                AMARELA                           120045.0
# 4                 BRANCA                           120010.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                    RIO BRANCO  ...
# 1                      10.0               RODRIGUES ALVES  ...
# 2                      10.0                    RIO BRANCO  ...
# 3                      10.0              SENADOR GUIOMARD  ...
# 4                      10.0                     BRASILEIA  ...
#
#   vacina_categoria_codigo vacina_categoria_nome  vacina_lote  \
# 0                     2.0          Faixa Etária       FA9096
# 1                     7.0       Povos Indígenas       GF9670
# 2                     2.0          Faixa Etária       FD7208
# 3                     2.0          Faixa Etária   21PVCD368Z
# 4                   114.0                Outros   21OVCD350Z
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                 PFIZER   Organization/00394544000851           2021-08-11
# 1                 PFIZER                         28290           2023-04-17
# 2                 PFIZER   Organization/00394544000851           2021-09-11
# 3    ASTRAZENECA/FIOCRUZ                           149           2022-07-23
# 4    ASTRAZENECA/FIOCRUZ                           149           2022-06-21
#
#   vacina_descricao_dose  vacina_codigo  \
# 0               1ª Dose             87
# 1               Reforço            103
# 2               1ª Dose             87
# 3               Reforço             85
# 4               Reforço             85
#
#                                  vacina_nome sistema_origem
# 0                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 1      COVID-19 PFIZER - COMIRNATY BIVALENTE       Novo PNI
# 2                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 3  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 4  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
#
# [5 rows x 32 columns]

# %%
# 1) Sua solução aqui

print(df['vacina_nome'].unique())
df['vacina_nome'].nunique()
# Out:
# ['COVID-19 PFIZER - COMIRNATY' 'COVID-19 PFIZER - COMIRNATY BIVALENTE'
#  'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD' 'INF3'
#  'COVID-19 JANSSEN - Ad26.COV2.S' 'COVID-19 SINOVAC - CORONAVAC'
#  'COVID-19 PEDIÁTRICA - PFIZER COMIRNATY'
#  'COVID-19 SINOVAC/BUTANTAN - CORONAVAC'
#  'COVID-19 ASTRAZENECA - ChAdOx1-S'
#  'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR DE 5 ANOS'
#  'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA' nan 'VVBN']
# 12

# %%
# 2)
df['paciente_id'].nunique()
# Out:
# 314797

# %%
# 3)
df_copy = df

df_copy['fl_1dose'] = 0

df_copy.loc[df_copy['vacina_descricao_dose'] == '1ª Dose', 'fl_1dose'] = 1

sum(df_copy['fl_1dose'])
# Out:
# 142985

# %%
# 3) solução alternativa
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df_primeira_dose = df[df['vacina_descricao_dose'] == primeira_dose]
df_primeira_dose['paciente_id'].nunique()
# Out:
# 142680

# %%
# 4)
df_menor = df[df["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 67032

# %%
# 5)
print(df['estabelecimento_razaoSocial'].unique())

df['estabelecimento_razaoSocial'].nunique()
# Out:
# ['PREFEITURA MUNICIPAL DE RIO BRANCO'
#  'DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO JURUA'
#  'PREFEITURA MUNICIPAL DE EPITACIOLANDIA'
#  'PREFEITURA MUNICIPAL DE TARAUACA' 'PREFEITURA MUNICIPAL DE FEIJO'
#  'PREFEITURA MUNICIPAL DE SAUDE' 'PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL'
#  'PREFEITURA MUNICIIPAL DE SENA MADUREIRA'
#  'PREFEITURA MUNICIPAL DE SENA MADUREIRA'
#  'PREFEITURA MUNICIPAL DE ASSIS BRASIL'
#  'PREFEITURA MUNICIPAL DE PORTO ACRE' 'SECRETARIA MUNICIPAL DE SAUDE'
#  'PREFEITURA MUNICIPAL DE SENADOR GUIOMARD'
#  'PREFEITURA MUNICIPAL DE MANCIO LIMA' 'REDE DE FRIOS'
#  'PREFEITURA MUNICIPAL DE MANUEL URBANO'
#  'PREFEITURA MUNICIPAL DE BRASILEIA'
#  'DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA'
#  'PREFEITURA MUN DE MAL THAUMATURGO' 'PREFEITURA MUNICIPAL DE XAPURI'
#  'POLO BASE DE TARAUACA' 'SECRETARIA DE ESTADO DE SAUDE'
#  'PREFEITURA MUNICIPAL DE ACRELANDIA' 'MUNICIPIO DE RIO BRANCO'
#  'DISTRITO SANITARIO ESPECIAL DE SAUDE INDIGENA ALTO RIO PURUS'
#  'PREFEITURA MUNICIPAL DE CAPIXABA'
#  'PREFEITURA MUNICIPAL DE RODRIGUES ALVES' 'SECRETARIA MUNCIPAL DE SAUDE'
#  'DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO PURUS'
#  'PREFEITURA MUNICIPAL DE JORDAO' 'PREFEITURA MUNICIPAL MANCIO LIMA'
#  'PREFEITURA MUNICIPAL DE PORTO WALTER'
#  'MUNICIPIO DE MARECHAL THAUMATURGO' 'MUNICIPIO DE MANCIO LIMA'
#  'PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS' 'USF AEROPORTO VELHO'
#  'MUNICIPIO DE SANTA ROSA DO PURUS'
#  'SECRETARIA DE ESTADO DE SAUDE DO ACRE' 'MINISTERIO DA SAUDE'
#  'PREFEITURA DE BRASILEIA' 'MUNICIPIO DE PORTO WALTER'
#  'PREFEITURA MUNICIPAL DE BUJARI' 'PREFEITURA DE MANCIO LIMA'
#  'PREFEITURA DE SENA MADUREIRA' '61 BIS' 'USF LIDIA RODRIGUES'
#  'PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO' 'USF BARRO VERMELHO'
#  'PREFEITURA MUNICIPAL DE SENADOR' 'MUNICIPIO DE BRASILEIA'
#  'SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA' 'K M OLIVEIRA EIRELI'
#  'A M COMERCIO E REPRESENTACOES LTDA' 'PORTO WALTER'
#  'PREFEITURA MUNICIPAL DE DE PLACIDO DE CASTRO' 'LUIZ AUGUSTO NO BATISTA'
#  'CENTRO DE DIAGNOSTICOS CITOLAB LTDA'
#  'CENTRAL MUNICIPAL DE REDE DE FRIOS' 'PRFEITURA MUNICIPAL DE ACRELANDIA']
# 59

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_18_menos = df[df['paciente_idade'] < 18]

df_18_menos
# Out:
#                                       document_id  \
# 0       c4fe1c06-9d03-4fb3-9f09-d03ae04172ed-i0b0
# 2       ea959b1f-c617-41f3-9114-3b3d8e6efb74-i0b0
# 4       f8c190bd-99f5-4426-8660-287026cb8f38-i0b0
# 8       60189586-61ef-409c-9e28-ec97118fc150-i0b0
# 10      8c22ac97-5efd-402c-b080-9152e17c93b9-i0b0
# ...                                           ...
# 384589  b57b8657-938f-4c95-afbd-4eeac3bbbca7-i0b0
# 384598  b74c7608-5317-451e-9119-c6abcb3f0d33-i0b0
# 384604  b8192620-cbb6-4d58-adfc-7e8cc5cb5f85-i0b0
# 384605  b82a04f3-d3c9-4ebc-b33f-08996656879f-i0b0
# 384608  b855b09d-6a74-4de8-90bc-ee220a19091b-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       b04dc8dc9a414410e7defb82eedd78ffeba9326ffe2a5e...              14
# 2       c71ae47ddab9e6bf4268c9d247781644a51f606208aa2f...              17
# 4       146286fb0daf52953daa7aa2fb5b8dffc16a53269530aa...              17
# 8       60a6b4d8d110395ae61e0b76969a3ed9daaeea34f93943...              17
# 10      5106e70d091093c2e990afb09ef7300fa1ae0cc0b3ca47...              11
# ...                                                   ...             ...
# 384589  cf76236f120de115a9d5e2f116d18ffdac49eb16b66fe5...               7
# 384598  781999be53c11eac706fbd47eafe0f3e6423b520337585...              10
# 384604  6e08b0bb0ea5d4c40f631180e20120d8cb0067dd03ec25...              13
# 384605  973c075616765b9a1fd249b89c51d89cc67ff8548eca10...              14
# 384608  2eb1ceb9bf6a3433d74948e45bbd1db7db295094fa343c...              13
#
#        paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                   2007-04-05                          F
# 2                   2003-12-31                          F
# 4                   2004-10-30                          M
# 8                   2004-04-30                          M
# 10                  2012-11-09                          F
# ...                        ...                        ...
# 384589              2016-06-01                          M
# 384598              2012-04-19                          F
# 384604              2007-09-06                          F
# 384605              2008-01-07                          M
# 384608              2008-01-25                          F
#
#         paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                            99         SEM INFORMACAO
# 2                             4                AMARELA
# 4                             1                 BRANCA
# 8                             3                  PARDA
# 10                            3                  PARDA
# ...                         ...                    ...
# 384589                        3                  PARDA
# 384598                        3                  PARDA
# 384604                        4                AMARELA
# 384605                        3                  PARDA
# 384608                        4                AMARELA
#
#         paciente_endereco_coIbgeMunicipio  paciente_endereco_coPais  \
# 0                                120040.0                      10.0
# 2                                120040.0                      10.0
# 4                                120010.0                      10.0
# 8                                120020.0                      10.0
# 10                               120040.0                      10.0
# ...                                   ...                       ...
# 384589                           120032.0                      10.0
# 384598                                NaN                       NaN
# 384604                           120040.0                      10.0
# 384605                           120040.0                      10.0
# 384608                           120030.0                      10.0
#
#        paciente_endereco_nmMunicipio  ... vacina_categoria_nome vacina_lote  \
# 0                         RIO BRANCO  ...          Faixa Etária      FA9096
# 2                         RIO BRANCO  ...          Faixa Etária      FD7208
# 4                          BRASILEIA  ...                Outros  21OVCD350Z
# 8                    CRUZEIRO DO SUL  ...                Outros      FF5107
# 10                        RIO BRANCO  ...          Faixa Etária      230147
# ...                              ...  ...                   ...         ...
# 384589                        JORDAO  ...          Faixa Etária      230165
# 384598                           NaN  ...                   NaN   202010040
# 384604                    RIO BRANCO  ...          Faixa Etária      FA9096
# 384605                    RIO BRANCO  ...          Faixa Etária      FT7280
# 384608                         FEIJO  ...                Outros      FD7221
#
#         vacina_fabricante_nome vacina_fabricante_referencia  \
# 0                       PFIZER  Organization/00394544000851
# 2                       PFIZER  Organization/00394544000851
# 4          ASTRAZENECA/FIOCRUZ                          149
# 8                       PFIZER  Organization/00394544000851
# 10                    BUTANTAN                          152
# ...                        ...                          ...
# 384589                BUTANTAN                          152
# 384598        SINOVAC/BUTANTAN                          152
# 384604                  PFIZER  Organization/00394544000851
# 384605                  PFIZER                        28290
# 384608                  PFIZER  Organization/00394544000851
#
#         vacina_dataAplicacao vacina_descricao_dose vacina_codigo  \
# 0                 2021-08-11               1ª Dose            87
# 2                 2021-09-11               1ª Dose            87
# 4                 2022-06-21               Reforço            85
# 8                 2021-09-20               2ª Dose            87
# 10                2023-11-30                 Única            33
# ...                      ...                   ...           ...
# 384589            2024-02-20                 Única            33
# 384598            2022-07-15               2ª Dose            86
# 384604            2021-08-12               1ª Dose            87
# 384605            2022-07-08               2ª Dose            87
# 384608            2021-08-12               1ª Dose            87
#
#                                       vacina_nome sistema_origem fl_1dose
# 0                     COVID-19 PFIZER - COMIRNATY       Novo PNI        1
# 2                     COVID-19 PFIZER - COMIRNATY       Novo PNI        1
# 4       COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI        0
# 8                     COVID-19 PFIZER - COMIRNATY       Novo PNI        0
# 10                                           INF3       Novo PNI        0
# ...                                           ...            ...      ...
# 384589                                       INF3       Novo PNI        0
# 384598      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI        0
# 384604                COVID-19 PFIZER - COMIRNATY       Novo PNI        1
# 384605                COVID-19 PFIZER - COMIRNATY       Novo PNI        0
# 384608                COVID-19 PFIZER - COMIRNATY       Novo PNI        1
#
# [75699 rows x 33 columns]

# %%
# 2)
df_18_menos.columns.tolist()
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem',
#  'fl_1dose']

# %%
# 3)
df_18_menos['vacina_categoria_nome'].count()
# Out:
# 55774

# %%
# 4)

df_18_menos.loc[:,'estabelecimento_valor':'estabelecimento_uf':].columns.tolist()
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
# 5)
df_18_menos[['estabelecimento_valor', 'estabelecimento_razaoSocial', 'estalecimento_noFantasia', 'estabelecimento_municipio_codigo', 
             'estabelecimento_municipio_nome', 'estabelecimento_uf']]
# Out:
#         estabelecimento_valor  \
# 0                     6917291
# 2                     6917291
# 4                     2001314
# 8                     7247435
# 10                    2000261
# ...                       ...
# 384589                5354072
# 384598                9648968
# 384604                6917291
# 384605                6917291
# 384608                2000040
#
#                               estabelecimento_razaoSocial  \
# 0                      PREFEITURA MUNICIPAL DE RIO BRANCO
# 2                      PREFEITURA MUNICIPAL DE RIO BRANCO
# 4                  PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 8                           PREFEITURA MUNICIPAL DE SAUDE
# 10                PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# ...                                                   ...
# 384589                     PREFEITURA MUNICIPAL DE JORDAO
# 384598  DISTRITO SANITARIO ESPECIAL DE SAUDE INDIGENA ...
# 384604                 PREFEITURA MUNICIPAL DE RIO BRANCO
# 384605                 PREFEITURA MUNICIPAL DE RIO BRANCO
# 384608                      PREFEITURA MUNICIPAL DE FEIJO
#
#                                  estalecimento_noFantasia  \
# 0       DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 2       DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 4                                 ESF JOAO ALVES DA SILVA
# 8       UNIDADE DE SAUDE DA FAMILIA RAIMUNDO CELSO LIM...
# 10                 UNIDADE DE SAUDE DA FAMILIA PROF QUITA
# ...                                                   ...
# 384589  UNIDADE DE SAUDE DA FAMILIA ANTONIO RODRIGUES ...
# 384598                     POLO INDIGENA DE MANOEL URBANO
# 384604  DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 384605  DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 384608                  CENTRO DE SAUDE DIAMANTINO MACEDO
#
#         estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 0                                 120040                     RIO BRANCO
# 2                                 120040                     RIO BRANCO
# 4                                 120025                 EPITACIOLANDIA
# 8                                 120020                CRUZEIRO DO SUL
# 10                                120020                CRUZEIRO DO SUL
# ...                                  ...                            ...
# 384589                            120032                         JORDAO
# 384598                            120034                  MANOEL URBANO
# 384604                            120040                     RIO BRANCO
# 384605                            120040                     RIO BRANCO
# 384608                            120030                          FEIJO
#
#        estabelecimento_uf
# 0                      AC
# 2                      AC
# 4                      AC
# 8                      AC
# 10                     AC
# ...                   ...
# 384589                 AC
# 384598                 AC
# 384604                 AC
# 384605                 AC
# 384608                 AC
#
# [75699 rows x 6 columns]

# %%
# 6)

df_estabelecimentos = df_18_menos.drop_duplicates('estabelecimento_razaoSocial')

df_estabelecimentos[['estabelecimento_valor','estalecimento_noFantasia','estabelecimento_municipio_codigo',
                    'estabelecimento_municipio_nome','estabelecimento_uf']]
# Out:
#         estabelecimento_valor  \
# 0                     6917291
# 4                     2001314
# 8                     7247435
# 10                    2000261
# 15                    2002566
# 53                    2000660
# 55                    6430201
# 58                    2003066
# 81                    6612385
# 89                    2003198
# 99                    2000164
# 135                   2001349
# 142                    924490
# 159                   7625855
# 167                   2002876
# 183                   6289312
# 184                   2002132
# 197                    468363
# 203                   2001217
# 235                   2002272
# 289                   2002221
# 294                   2000016
# 412                   2000962
# 449                   3006166
# 490                   2002922
# 584                   5354072
# 688                   5981891
# 751                   3959082
# 795                   2001772
# 863                   2001128
# 937                   2001748
# 979                   9648968
# 989                   2001039
# 1422                   899593
# 4287                  9948759
# 6200                  3516822
# 6220                  9908382
# 6901                  9014896
# 7574                  6697151
# 11977                 7959087
# 13743                  117382
# 26301                 9830464
# 26404                 9542566
# 27632                 2001012
# 37038                  115606
# 38024                 6607861
# 67714                  499919
# 119693                7617852
# 129065                2001357
# 135718                 197599
# 188110                5493455
# 228482                 755605
#
#                                  estalecimento_noFantasia  \
# 0       DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 4                                 ESF JOAO ALVES DA SILVA
# 8       UNIDADE DE SAUDE DA FAMILIA RAIMUNDO CELSO LIM...
# 10                 UNIDADE DE SAUDE DA FAMILIA PROF QUITA
# 15          UNIDADE BASICA DE SAUDE LAURO FONTES DA SILVA
# 53            CENTRO DE SAUDE MARIA DO SOCORRO CAVALCANTE
# 55                                     POLO BASE INDIGENA
# 58      UNIDADE BASICA DE SAUDE TEREZINHA BATISTA DOS ...
# 81      UNIDADE ASSISTENCIAL A SAUDE INDIGENA DE TARAU...
# 89                            URAP MARIA BARROSO DA SILVA
# 99               UNIDADE DE SAUDE DA FAMILIA MARIA DA LUZ
# 135                                ESF TUFIC MIZAEL SAADY
# 142     UNIDADE MOVEL DE SAUDE FLUVIAL PEDRO RODRIGUES...
# 159                     POLO BASE DE MARECHAL THAUMATURGO
# 167      CENTRO DE SAUDE RAIMUNDA PORFIRIO DE BRITO RAMOS
# 183                      POLO BASE DE SANTA ROSA DO PURUS
# 184                      ESF RIBEIRINHA DR NALDIR MARIANO
# 197                                         REDE DE FRIOS
# 203                   UNIDADE SAUDE DA FAMILIA JOSE FADUL
# 235                        UNIDADE S FAMILIA DR CERQUEIRA
# 289                               U S F FRANCISCO ALENCAR
# 294                    UNIDADE BASICA PADRE TEODORO ARNDS
# 412                         UNIDADE DE SAUDE JOSEFA NUNES
# 449     UNIDADE DE SAUDE DA FAMILIA NORTON VITORINO BOHEN
# 490                                    U S F JOAO DE DEUS
# 584     UNIDADE DE SAUDE DA FAMILIA ANTONIO RODRIGUES ...
# 688                      UNIDADE BASICA DE SAUDE MODULO I
# 751                          UNIDADE MISTA DE SANTA LUZIA
# 795                 CENTRO DE SAUDE PAULO ALCIONE MARQUES
# 863     UNIDADE DE SAUDE DA FAMILIA MARIA SOLEDADE SOA...
# 937                                  UBS ESTEPHAN BARBARY
# 979                         UNIDADE BASICA DE SAUDE BUACU
# 989     UNIDADE DE SAUDE DA FAMILIA DR LUIZ FERNANDO M...
# 1422                           UBS LINA BANDEIRA DA ROCHA
# 4287         ESF RAIMUNDA ANTONIA DE ARAUJO CARNEIRO LIMA
# 6200                                         USF ANTIMARY
# 6220                                  USF AEROPORTO VELHO
# 6901                        USF RAIMUNDO GOMES DE AZEVEDO
# 7574      DISTRITO SANITARIO ESPECIAL INDIGENA ALTO PURUS
# 11977                   UBS MAURICIO PINHEIRO DE OLIVEIRA
# 13743                                 USF LIDIA RODRIGUES
# 26301                         ESF ANTONIO CORREIA DA CRUZ
# 26404                   UBS RAIMUNDO REGINALDO DE ALMEIDA
# 27632                               USF MOCINHA MAGALHAES
# 37038                              MAIS SAUDE DIAGNOSTICO
# 38024   UNIDADE DE SAUDE DA FAMILIA MIGUEL SEVERINO DE...
# 67714              UNIDADE BASICA DE SAUDE MANDUCA KULINA
# 119693              UNIDADE BASICA DE SAUDE JOVILIO ALVES
# 129065                        ESF PEDRO OLIVEIRA DE SOUZA
# 135718                 CENTRAL MUNICIPAL DE REDE DE FRIOS
# 188110                         U S F MARIO GOMES DA SILVA
# 228482                                 USF BARRO VERMELHO
#
#         estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 0                                 120040                     RIO BRANCO
# 4                                 120025                 EPITACIOLANDIA
# 8                                 120020                CRUZEIRO DO SUL
# 10                                120020                CRUZEIRO DO SUL
# 15                                120050                 SENA MADUREIRA
# 53                                120045               SENADOR GUIOMARD
# 55                                120032                         JORDAO
# 58                                120005                   ASSIS BRASIL
# 81                                120060                       TARAUACA
# 89                                120040                     RIO BRANCO
# 99                                120060                       TARAUACA
# 135                               120010                      BRASILEIA
# 142                               120030                          FEIJO
# 159                               120035           MARECHAL THAUMATURGO
# 167                               120013                         BUJARI
# 183                               120043            SANTA ROSA DO PURUS
# 184                               120035           MARECHAL THAUMATURGO
# 197                               120033                    MANCIO LIMA
# 203                               120070                         XAPURI
# 235                               120033                    MANCIO LIMA
# 289                               120033                    MANCIO LIMA
# 294                               120042                RODRIGUES ALVES
# 412                               120034                  MANOEL URBANO
# 449                               120001                     ACRELANDIA
# 490                               120038              PLACIDO DE CASTRO
# 584                               120032                         JORDAO
# 688                               120050                 SENA MADUREIRA
# 751                               120020                CRUZEIRO DO SUL
# 795                               120043            SANTA ROSA DO PURUS
# 863                               120080                     PORTO ACRE
# 937                               120039                   PORTO WALTER
# 979                               120034                  MANOEL URBANO
# 989                               120017                       CAPIXABA
# 1422                              120033                    MANCIO LIMA
# 4287                              120010                      BRASILEIA
# 6200                              120013                         BUJARI
# 6220                              120040                     RIO BRANCO
# 6901                              120035           MARECHAL THAUMATURGO
# 7574                              120050                 SENA MADUREIRA
# 11977                             120039                   PORTO WALTER
# 13743                             120040                     RIO BRANCO
# 26301                             120010                      BRASILEIA
# 26404                             120033                    MANCIO LIMA
# 27632                             120040                     RIO BRANCO
# 37038                             120020                CRUZEIRO DO SUL
# 38024                             120045               SENADOR GUIOMARD
# 67714                             120043            SANTA ROSA DO PURUS
# 119693                            120050                 SENA MADUREIRA
# 129065                            120010                      BRASILEIA
# 135718                            120020                CRUZEIRO DO SUL
# 188110                            120038              PLACIDO DE CASTRO
# 228482                            120040                     RIO BRANCO
#
#        estabelecimento_uf
# 0                      AC
# 4                      AC
# 8                      AC
# 10                     AC
# 15                     AC
# 53                     AC
# 55                     AC
# 58                     AC
# 81                     AC
# 89                     AC
# 99                     AC
# 135                    AC
# 142                    AC
# 159                    AC
# 167                    AC
# 183                    AC
# 184                    AC
# 197                    AC
# 203                    AC
# 235                    AC
# 289                    AC
# 294                    AC
# 412                    AC
# 449                    AC
# 490                    AC
# 584                    AC
# 688                    AC
# 751                    AC
# 795                    AC
# 863                    AC
# 937                    AC
# 979                    AC
# 989                    AC
# 1422                   AC
# 4287                   AC
# 6200                   AC
# 6220                   AC
# 6901                   AC
# 7574                   AC
# 11977                  AC
# 13743                  AC
# 26301                  AC
# 26404                  AC
# 27632                  AC
# 37038                  AC
# 38024                  AC
# 67714                  AC
# 119693                 AC
# 129065                 AC
# 135718                 AC
# 188110                 AC
# 228482                 AC
